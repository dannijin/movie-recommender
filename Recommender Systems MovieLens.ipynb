# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display floats with 3 digits
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

# %%
colnames = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=colnames)

df.head(2)
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949

# %%
movie_titles = pd.read_csv("Movie_Id_Titles")
movie_titles.head(2)
# Out:
#    item_id             title
# 0        1  Toy Story (1995)
# 1        2  GoldenEye (1995)

# %%
df = pd.merge(df, movie_titles, on='item_id')
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %% [markdown]
# Our dataframe is currently a list of records, with each containing a user, a movie, and a rating. We need to rearrange this data so the columns represent movies and the rows represent users. To do this, we'll use `pd.pivot_table()`.

# %%
ratings = pd.pivot_table(
    data=df,
    values='rating',
    index='user_id',
    columns='title'
)

ratings.head(10)
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              nan           nan                    nan
# 1                              nan           nan                  2.000
# 2                              nan           nan                    nan
# 3                              nan           nan                    nan
# 4                              nan           nan                    nan
# 5                              nan           nan                  2.000
# 6                              nan           nan                    nan
# 7                              nan           nan                    nan
# 8                              nan           nan                    nan
# 9                              nan           nan                    nan
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        nan         nan                          nan
# 1                      5.000         nan                          nan
# 2                        nan         nan                          nan
# 3                        nan       2.000                          nan
# 4                        nan         nan                          nan
# 5                        nan         nan                          nan
# 6                      4.000         nan                          nan
# 7                      4.000         nan                          nan
# 8                        nan         nan                          nan
# 9                        nan         nan                          nan
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# 0                                        nan                           nan
# 1                                      3.000                         4.000
# 2                                        nan                           nan
# 3                                        nan                           nan
# 4                                        nan                           nan
# 5                                        nan                         4.000
# 6                                        nan                         5.000
# 7                                      5.000                         5.000
# 8                                        nan                           nan
# 9                                        nan                           nan
#
# title    3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# user_id
# 0                                                nan                   nan
# 1                                                nan                   nan
# 2                                              1.000                   nan
# 3                                                nan                   nan
# 4                                                nan                   nan
# 5                                                nan                   nan
# 6                                                nan                   nan
# 7                                                nan                 4.000
# 8                                                nan                   nan
# 9                                                nan                 4.000
#
# title                   ...                  Yankee Zulu (1994)  \
# user_id                 ...
# 0                       ...                                 nan
# 1                       ...                                 nan
# 2                       ...                                 nan
# 3                       ...                                 nan
# 4                       ...                                 nan
# 5                       ...                                 nan
# 6                       ...                                 nan
# 7                       ...                                 nan
# 8                       ...                                 nan
# 9                       ...                                 nan
#
# title    Year of the Horse (1997)  You So Crazy (1994)  \
# user_id
# 0                             nan                  nan
# 1                             nan                  nan
# 2                             nan                  nan
# 3                             nan                  nan
# 4                             nan                  nan
# 5                             nan                  nan
# 6                             nan                  nan
# 7                             nan                  nan
# 8                             nan                  nan
# 9                             nan                  nan
#
# title    Young Frankenstein (1974)  Young Guns (1988)  Young Guns II (1990)  \
# user_id
# 0                              nan                nan                   nan
# 1                            5.000              3.000                   nan
# 2                              nan                nan                   nan
# 3                              nan                nan                   nan
# 4                              nan                nan                   nan
# 5                            4.000                nan                   nan
# 6                            4.000                nan                   nan
# 7                            5.000              3.000                   nan
# 8                              nan                nan                   nan
# 9                              nan                nan                   nan
#
# title    Young Poisoner's Handbook, The (1995)  Zeus and Roxanne (1997)  \
# user_id
# 0                                          nan                      nan
# 1                                          nan                      nan
# 2                                          nan                      nan
# 3                                          nan                      nan
# 4                                          nan                      nan
# 5                                          nan                      nan
# 6                                          nan                      nan
# 7                                        3.000                      nan
# 8                                          nan                      nan
# 9                                          nan                      nan
#
# title    unknown  Á köldum klaka (Cold Fever) (1994)
# user_id
# 0            nan                                 nan
# 1          4.000                                 nan
# 2            nan                                 nan
# 3            nan                                 nan
# 4            nan                                 nan
# 5          4.000                                 nan
# 6            nan                                 nan
# 7            nan                                 nan
# 8            nan                                 nan
# 9            nan                                 nan
#
# [10 rows x 1664 columns]

# %% [markdown]
# We have a lot of missing values, and we're going to replace them with the user's average rating across all the movies they've rated.
#
# First we'll **transpose** the dataframe. This will turn it on its side so columns are now rows and vice-versa.
#
# The quickest way to transpose a dataframe is to just add `.T`  as an attribute.

# %%
users = ratings.T.fillna(0)

# %% [markdown]
# Now we're going to convert ratings into **z-scores**. A z-score represents how many standard deviations a rating is from the user's average rating. It's a great way to normalize data; the intuition is that a "5" means a lot more coming from a user whose average rating is a 2, than one whose average rating is a 4.

# %%
# Calculate z-score based on non-zero ratings
users = np.where(
    users != 0,
    (users - users[users != 0].mean()) / users[users != 0].std(),
    0
)

users = pd.DataFrame(users, index=ratings.columns)

# Highest rated movies first
users.mean(axis='columns').sort_values(ascending=False).head(10)
# Out:
# title
# Star Wars (1977)                   0.462
# Godfather, The (1972)              0.300
# Fargo (1996)                       0.293
# Raiders of the Lost Ark (1981)     0.283
# Silence of the Lambs, The (1991)   0.274
# Schindler's List (1993)            0.268
# Titanic (1997)                     0.254
# Shawshank Redemption, The (1994)   0.244
# Empire Strikes Back, The (1980)    0.226
# Return of the Jedi (1983)          0.220
# dtype: float64

# %% [markdown]
# This favors movies with lots of ratings. It's not a perfect system, but it'll work for our purposes.
#
# Now we're going to rebuild the ratings dataframe by transposing back our users' data.

# %%
ratings = pd.DataFrame(users.T, columns=users.index)

ratings.head()
# Out:
# title  'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# 0                          0.000         0.000                  0.000
# 1                          0.000         0.000                 -1.271
# 2                          0.000         0.000                  0.000
# 3                          0.000         0.000                  0.000
# 4                          0.000         0.000                  0.000
#
# title  12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# 0                    0.000       0.000                        0.000
# 1                    1.104       0.000                        0.000
# 2                    0.000       0.000                        0.000
# 3                    0.000      -0.635                        0.000
# 4                    0.000       0.000                        0.000
#
# title  20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# 0                                    0.000                         0.000
# 1                                   -0.479                         0.313
# 2                                    0.000                         0.000
# 3                                    0.000                         0.000
# 4                                    0.000                         0.000
#
# title  3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# 0                                            0.000                 0.000
# 1                                            0.000                 0.000
# 2                                           -2.605                 0.000
# 3                                            0.000                 0.000
# 4                                            0.000                 0.000
#
# title                 ...                  Yankee Zulu (1994)  \
# 0                     ...                               0.000
# 1                     ...                               0.000
# 2                     ...                               0.000
# 3                     ...                               0.000
# 4                     ...                               0.000
#
# title  Year of the Horse (1997)  You So Crazy (1994)  \
# 0                         0.000                0.000
# 1                         0.000                0.000
# 2                         0.000                0.000
# 3                         0.000                0.000
# 4                         0.000                0.000
#
# title  Young Frankenstein (1974)  Young Guns (1988)  Young Guns II (1990)  \
# 0                          0.000              0.000                 0.000
# 1                          1.104             -0.479                 0.000
# 2                          0.000              0.000                 0.000
# 3                          0.000              0.000                 0.000
# 4                          0.000              0.000                 0.000
#
# title  Young Poisoner's Handbook, The (1995)  Zeus and Roxanne (1997)  \
# 0                                      0.000                    0.000
# 1                                      0.000                    0.000
# 2                                      0.000                    0.000
# 3                                      0.000                    0.000
# 4                                      0.000                    0.000
#
# title  unknown  Á köldum klaka (Cold Fever) (1994)
# 0        0.000                               0.000
# 1        0.313                               0.000
# 2        0.000                               0.000
# 3        0.000                               0.000
# 4        0.000                               0.000
#
# [5 rows x 1664 columns]

# %% [markdown]
# The `.corrwith()` method can compare an entire dataframe to a single column. It's quite useful for our recommender system.

# %%
ratings.corrwith(
    ratings['Ace Ventura: Pet Detective (1994)']).sort_values(
    ascending=False)
# Out:
# title
# Ace Ventura: Pet Detective (1994)                      1.000
# Naked Gun 33 1/3: The Final Insult (1994)              0.260
# Basic Instinct (1992)                                  0.256
# City Slickers II: The Legend of Curly's Gold (1994)    0.250
# Batman Forever (1995)                                  0.226
# Junior (1994)                                          0.219
# Dumb & Dumber (1994)                                   0.217
# Beverly Hillbillies, The (1993)                        0.216
# Young Guns II (1990)                                   0.214
# Dirty Dancing (1987)                                   0.212
# Fog, The (1980)                                        0.200
# Hot Shots! Part Deux (1993)                            0.199
# War, The (1994)                                        0.199
# Escape from New York (1981)                            0.192
# Alien 3 (1992)                                         0.188
# Gumby: The Movie (1995)                                0.184
# Ready to Wear (Pret-A-Porter) (1994)                   0.182
# Gordy (1995)                                           0.182
# Billy Madison (1995)                                   0.178
# Robin Hood: Men in Tights (1993)                       0.177
# Dracula: Dead and Loving It (1995)                     0.176
# Village of the Damned (1995)                           0.176
# Tommy Boy (1995)                                       0.176
# Home Alone (1990)                                      0.174
# Corrina, Corrina (1994)                                0.173
# Another Stakeout (1993)                                0.173
# Nightmare on Elm Street, A (1984)                      0.171
# Destiny Turns on the Radio (1995)                      0.170
# Addams Family Values (1993)                            0.163
# Last Action Hero (1993)                                0.162
#                                                        ...
# Collectionneuse, La (1967)                            -0.193
# Shadows (Cienie) (1988)                               -0.198
# Lashou shentan (1992)                                 -0.198
# Liebelei (1933)                                       -0.198
# Eye of Vichy, The (Oeil de Vichy, L') (1993)          -0.198
# Pharaoh's Army (1995)                                 -0.198
# Baton Rouge (1988)                                    -0.198
# Yankee Zulu (1994)                                    -0.198
# Wend Kuuni (God's Gift) (1982)                        -0.198
# Vermont Is For Lovers (1992)                          -0.198
# Vie est belle, La (Life is Rosey) (1987)              -0.198
# Touki Bouki (Journey of the Hyena) (1973)             -0.198
# Hungarian Fairy Tale, A (1987)                        -0.198
# Quartier Mozart (1992)                                -0.198
# Promise, The (Versprechen, Das) (1994)                -0.198
# To Cross the Rubicon (1991)                           -0.198
# The Courtyard (1995)                                  -0.198
# Tigrero: A Film That Was Never Made (1994)            -0.198
# Death in the Garden (Mort en ce jardin, La) (1956)    -0.198
# Woman in Question, The (1950)                         -0.198
# Invitation, The (Zaproszenie) (1986)                  -0.198
# Daens (1992)                                          -0.198
# Symphonie pastorale, La (1946)                        -0.198
# T-Men (1947)                                          -0.198
# Man from Down Under, The (1943)                       -0.198
# I, Worst of All (Yo, la peor de todas) (1990)         -0.198
# Hostile Intentions (1994)                             -0.198
# Terror in a Texas Town (1958)                         -0.198
# Careful (1992)                                        -0.198
# Spirits of the Dead (Tre passi nel delirio) (1968)    -0.207
# Length: 1664, dtype: float64

# %%
# We might as well make a function out of it. So here it is:

def recommended_movies(movie):
    recs = ratings.corrwith(ratings[movie]).sort_values(ascending=False)
    
    # Only return movies with a decently high correlation
    recs = recs[recs > 0.2]
    
    # Remove the movie itself
    recs = recs[recs < .99]
    
    return recs

recommended_movies('Back to the Future (1985)')
# Out:
# title
# Indiana Jones and the Last Crusade (1989)   0.344
# Raiders of the Lost Ark (1981)              0.344
# Terminator 2: Judgment Day (1991)           0.280
# Speed (1994)                                0.262
# Fugitive, The (1993)                        0.260
# Terminator, The (1984)                      0.258
# Empire Strikes Back, The (1980)             0.244
# Die Hard (1988)                             0.240
# Return of the Jedi (1983)                   0.238
# Field of Dreams (1989)                      0.228
# Jurassic Park (1993)                        0.227
# Aladdin (1992)                              0.216
# Apollo 13 (1995)                            0.215
# Star Trek: The Wrath of Khan (1982)         0.211
# Blues Brothers, The (1980)                  0.203
# dtype: float64
